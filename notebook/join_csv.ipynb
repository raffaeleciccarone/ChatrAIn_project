# %%
import pandas as pd

df_bench = pd.read_csv('/Users/raffaeleciccarone/Desktop/ChatrAIn_project_ibm/csv_test/benchmark_log.csv')
df_chat = pd.read_csv('/Users/raffaeleciccarone/Desktop/ChatrAIn_project_ibm/csv_test/test_chatrain.csv')

# %%
df_bench
# Out:
#       model   time                                 query  \
# 0    llama3  43.39  come si chiamano le ruote del treno?
# 1   mistral  43.11  come si chiamano le ruote del treno?
# 2    llama3  54.37               come faccio prova freno
# 3  llama3.2  14.77               come faccio prova freno
#
#                                             response
# 0  Non sono menzionati nel contesto specifici nom...
# 1   Nella descrizione fornita, non ci sono indica...
# 2  In base al contesto fornito, non è possibile t...
# 3  Mi dispiace, non ho informazioni specifiche su...

# %%
df_chat
# Out:
#        model   time                                              query  \
# 0     llama3  90.94                                             test_T
# 1     llama3  58.84  Come effettuare la manutenzione ordinaria dei ...
# 2   llama3.2  33.24  Come effettuare la manutenzione ordinaria dei ...
# 3     llama3  69.44  quali sono le procedure per la sostituzione de...
# 4   llama3.2  13.31  quali sono le procedure per la sostituzione de...
# 5     llama3  89.03   come si esegue la prova freno a banco sul treno?
# 6   llama3.2  14.99   come si esegue la prova freno a banco sul treno?
# 7     llama3  57.22  come si ispezionano le sale del treno durante ...
# 8   llama3.2  21.67  come si ispezionano le sale del treno durante ...
# 9     llama3  54.50  quali controlli non distruttivi sono previsti ...
# 10  llama3.2  14.10  quali controlli non distruttivi sono previsti ...
# 11  llama3.2  24.53  Come effettuare la manutenzione ordinaria dei ...
#
# ...

# %%
new_df = pd.concat([df_chat, df_bench], ignore_index=True)

# %%
new_df.to_csv('/Users/raffaeleciccarone/Desktop/ChatrAIn_project_ibm/csv_test/benchmark_log.csv',index=False)
